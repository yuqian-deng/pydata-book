# %% [markdown]
# ### Tab Completion
# 1. search the interactive namespace
# 2. complete object or module attributes
# 3. complete file path

# %% [markdown]
# ### Introspection

# %%
def add_numbers(a,b):
    """
    Add two numbers together
    Returns
    ---------
    the_sum: type of arguments
    """
    return a+b

# %%
# ?add_numbers

# %%
# ?? show the function's source code
??add_numbers

# %%
# ? search namespace
import numpy as np
np.*load*?

# %% [markdown]
# ### The %run command

# %% [markdown]
# ### Magic Commands
# 1. %timeit Check the execution time of Python statement
# 2. %reset Resets the namespaceby removing all names defined by the user
# 3. %logstart
# 4. %automagic
# 5. %magic

# %%
# Interacting with the Operating System

# %%
# !Python
# Out:
# ^C

# %%
pwd
# Out:
# 'C:\\Users\\yuqia\\pydata-book'

# %%
# Directory Bookmark System
# %bookmark db /Users/yuqia/pydata-book

# %%
cd db
# Out:
# (bookmark:db) -> /Users/yuqia/pydata-book
# C:\Users\yuqia\pydata-book

# %%
# %bookmark -l
# Out:
# Current bookmarks:
# db -> /Users/yuqia/pydata-book

# %%
# Timing Code: %time and %timeit
strings = ['foo','foobar','baz','qux','python','GUido Van Rossum'] * 100000
method1 = [x for x in strings if x.startswith('foo')]
method2 = [x for x in strings if x[:3] == 'foo']

# %%
# %time method1 = [x for x in strings if x.startswith('foo')]
# Out:
# Wall time: 96.6 ms

# %%
# %time method2 = [x for x in strings if x[:3] == 'foo']
# Out:
# Wall time: 84.4 ms

# %%
# %timeit method1 = [x for x in strings if x.startswith('foo')]
# Out:
# 93.8 ms ± 4.63 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit method2 = [x for x in strings if x[:3] == 'foo']
# Out:
# 88.2 ms ± 8.45 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
pwd
# Out:
# 'C:\\Users\\yuqia\\pydata-book'

# %%
# Basic Profiling: %prun and %run -p

# %%
# !python -m cProfile -s cumulative cprof_example.py
# Out:
#          66547 function calls (64365 primitive calls) in 0.193 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        12    0.001    0.000    0.400    0.033 __init__.py:1(<module>)
#     436/1    0.001    0.000    0.193    0.193 {built-in method builtins.exec}
#         1    0.000    0.000    0.193    0.193 cprof_example.py:1(<module>)
#     152/1    0.001    0.000    0.193    0.193 <frozen importlib._bootstrap>:986(_find_and_load)
#     152/1    0.001    0.000    0.193    0.193 <frozen importlib._bootstrap>:956(_find_and_load_unlocked)
#     143/1    0.001    0.000    0.193    0.193 <frozen importlib._bootstrap>:650(_load_unlocked)
#     110/1    0.000    0.000    0.193    0.193 <frozen importlib._bootstrap_external>:777(exec_module)
#     221/1    0.000    0.000    0.192    0.192 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
# ...

# %%
import numpy as np
from numpy.linalg import eigvals

def run_experiment(niter=100):
	k=100
	results = []
	for _ in range(niter):
		mat = np.random.randn(k,k)
		max_eigenvalue = np.abs(eigvals(mat)).max()
		results.append(max_eigenvalue)
	return results

# %%
# %prun -l 7 -s cumulative run_experiment()

# %%
# Profiling a Function Line-by-Line

# %%
from numpy.random import randn

def add_and_sum(x,y):
    added = x + y
    summed = added.sum(axis=1)
    return summed

def call_function():
    x = randn(1000,1000)
    y = randn(1000,1000)
    return add_and_sun(x,y)

# %%
x = randn(3000,3000)
y = randn(3000,3000)
# %prun add_and_sum(x,y)

# %%
# Reloading Module Dependencies

# %%
# Making Your Own Classes IPython-friendly
class Message:
    def __init__(self,msg):
        self.msg = msg
        
x = Message('I have a secret')

# %%
x

# %%
class Message:
    def __init__(self,msg):
        self.msg = msg
        
    def __repr__(self):
        return 'Message: %s' % self.msg
        
x = Message('I have a secret')

# %%
x
# Out:
# Message: I have a secret
